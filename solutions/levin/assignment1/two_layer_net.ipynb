# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from cs231n.classifiers.neural_net import TwoLayerNet

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
# Out:
# /home/levin/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs231n/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
  np.random.seed(0)
  return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
  np.random.seed(1)
  X = 10 * np.random.randn(num_inputs, input_size)
  y = np.array([0, 1, 2, 2, 1])
  return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs231n/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print 'Your scores:'
print scores
print
print 'correct scores:'
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print correct_scores
print

# The difference should be very small. We get < 1e-7
print 'Difference between your scores and correct scores:'
print np.sum(np.abs(scores - correct_scores))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.68027207459e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.1)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print 'Difference between your loss and correct loss:'
print np.sum(np.abs(loss - correct_loss))
# Out:
# Difference between your loss and correct loss:
# 1.79412040779e-13

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cs231n.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.1)

# these should all be less than 1e-8 or so
for param_name in grads:
  f = lambda W: net.loss(X, y, reg=0.1)[0]
  param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
  print '%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name]))
# Out:
# W1 max relative error: 3.561318e-09
# W2 max relative error: 3.440708e-09
# b2 max relative error: 3.865070e-11
# b1 max relative error: 2.738421e-09

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=1e-5,
            num_iters=100, verbose=False)

print 'Final training loss: ', stats['loss_history'][-1]

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Epoch:0/100, Train accuracy:0.66, Validation accuracy:0.6, loss1.24199380249,update_ration_w1:1.9e-01,update_ration_w2:3.5e-01
# Epoch:1/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.911191368193,update_ration_w1:1.5e-01,update_ration_w2:1.7e-01
# Epoch:2/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.727969892134,update_ration_w1:1.1e-01,update_ration_w2:1.6e-01
# Epoch:3/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.587932152849,update_ration_w1:1.2e-01,update_ration_w2:1.2e-01
# Epoch:4/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.443400061889,update_ration_w1:1.0e-01,update_ration_w2:9.9e-02
# Epoch:5/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.321233370904,update_ration_w1:7.7e-02,update_ration_w2:7.8e-02
# Epoch:6/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.229576963542,update_ration_w1:6.0e-02,update_ration_w2:6.4e-02
# Epoch:7/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.191957542043,update_ration_w1:5.6e-02,update_ration_w2:5.6e-02
# Epoch:8/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.14265348386,update_ration_w1:3.8e-02,update_ration_w2:4.1e-02
# Epoch:9/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.122730900107,update_ration_w1:3.1e-02,update_ration_w2:3.1e-02
# Epoch:10/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0929652767698,update_ration_w1:2.3e-02,update_ration_w2:2.4e-02
# Epoch:11/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0779451526834,update_ration_w1:1.9e-02,update_ration_w2:1.9e-02
# Epoch:12/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0726255775649,update_ration_w1:1.7e-02,update_ration_w2:1.7e-02
# Epoch:13/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0653607005597,update_ration_w1:1.5e-02,update_ration_w2:1.5e-02
# Epoch:14/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0546204116275,update_ration_w1:1.2e-02,update_ration_w2:1.3e-02
# Epoch:15/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0455228924952,update_ration_w1:9.4e-03,update_ration_w2:1.0e-02
# Epoch:16/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0470183239777,update_ration_w1:9.3e-03,update_ration_w2:9.7e-03
# Epoch:17/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0429827176036,update_ration_w1:8.2e-03,update_ration_w2:8.6e-03
# Epoch:18/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0370036317375,update_ration_w1:6.9e-03,update_ration_w2:7.4e-03
# Epoch:19/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0361268313289,update_ration_w1:6.3e-03,update_ration_w2:6.5e-03
# Epoch:20/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0360553841641,update_ration_w1:6.2e-03,update_ration_w2:6.2e-03
# Epoch:21/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0329430256454,update_ration_w1:5.3e-03,update_ration_w2:5.5e-03
# Epoch:22/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0300608656737,update_ration_w1:4.5e-03,update_ration_w2:4.8e-03
# Epoch:23/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.031595094588,update_ration_w1:4.7e-03,update_ration_w2:4.9e-03
# Epoch:24/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0282885030296,update_ration_w1:4.0e-03,update_ration_w2:4.1e-03
# Epoch:25/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0292154716017,update_ration_w1:3.9e-03,update_ration_w2:4.1e-03
# Epoch:26/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0242750267681,update_ration_w1:3.1e-03,update_ration_w2:3.2e-03
# Epoch:27/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0263616628541,update_ration_w1:3.2e-03,update_ration_w2:3.3e-03
# Epoch:28/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0258490158686,update_ration_w1:3.0e-03,update_ration_w2:3.1e-03
# Epoch:29/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0245481639812,update_ration_w1:2.7e-03,update_ration_w2:2.8e-03
# Epoch:30/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0232917457963,update_ration_w1:2.4e-03,update_ration_w2:2.5e-03
# Epoch:31/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0212824538917,update_ration_w1:2.1e-03,update_ration_w2:2.2e-03
# Epoch:32/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0220038020509,update_ration_w1:2.1e-03,update_ration_w2:2.2e-03
# Epoch:33/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0219409149056,update_ration_w1:2.0e-03,update_ration_w2:2.0e-03
# Epoch:34/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0218111297892,update_ration_w1:1.8e-03,update_ration_w2:1.9e-03
# Epoch:35/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0213868506977,update_ration_w1:1.7e-03,update_ration_w2:1.8e-03
# Epoch:36/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0210600301898,update_ration_w1:1.7e-03,update_ration_w2:1.7e-03
# Epoch:37/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0203707711593,update_ration_w1:1.5e-03,update_ration_w2:1.5e-03
# Epoch:38/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0212098389855,update_ration_w1:1.5e-03,update_ration_w2:1.5e-03
# Epoch:39/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0186719021362,update_ration_w1:1.2e-03,update_ration_w2:1.3e-03
# Epoch:40/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0195038136243,update_ration_w1:1.2e-03,update_ration_w2:1.3e-03
# Epoch:41/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0191417580355,update_ration_w1:1.1e-03,update_ration_w2:1.2e-03
# Epoch:42/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0197164658389,update_ration_w1:1.1e-03,update_ration_w2:1.1e-03
# Epoch:43/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0175650399515,update_ration_w1:9.4e-04,update_ration_w2:9.8e-04
# Epoch:44/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0179025846884,update_ration_w1:9.0e-04,update_ration_w2:9.7e-04
# Epoch:45/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0162557750695,update_ration_w1:7.9e-04,update_ration_w2:8.4e-04
# Epoch:46/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0178096163351,update_ration_w1:8.2e-04,update_ration_w2:8.6e-04
# Epoch:47/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0154307946218,update_ration_w1:6.8e-04,update_ration_w2:7.1e-04
# Epoch:48/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.018846591389,update_ration_w1:7.9e-04,update_ration_w2:8.1e-04
# Epoch:49/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0180145599753,update_ration_w1:7.2e-04,update_ration_w2:7.3e-04
# Epoch:50/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0173117213438,update_ration_w1:6.5e-04,update_ration_w2:6.7e-04
# Epoch:51/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0178960542106,update_ration_w1:6.5e-04,update_ration_w2:6.7e-04
# Epoch:52/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0169850713406,update_ration_w1:5.8e-04,update_ration_w2:6.1e-04
# Epoch:53/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0178931447423,update_ration_w1:5.8e-04,update_ration_w2:6.0e-04
# Epoch:54/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0177205380972,update_ration_w1:5.5e-04,update_ration_w2:5.6e-04
# Epoch:55/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0160643762919,update_ration_w1:4.7e-04,update_ration_w2:4.9e-04
# Epoch:56/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0183440540465,update_ration_w1:5.2e-04,update_ration_w2:5.4e-04
# Epoch:57/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0178350039973,update_ration_w1:4.8e-04,update_ration_w2:4.8e-04
# Epoch:58/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0186926141307,update_ration_w1:4.7e-04,update_ration_w2:4.9e-04
# Epoch:59/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0174396637716,update_ration_w1:4.4e-04,update_ration_w2:4.3e-04
# Epoch:60/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0161753085733,update_ration_w1:3.7e-04,update_ration_w2:3.8e-04
# Epoch:61/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0185644209146,update_ration_w1:4.1e-04,update_ration_w2:4.1e-04
# Epoch:62/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0175718736932,update_ration_w1:3.6e-04,update_ration_w2:3.7e-04
# Epoch:63/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0158289063338,update_ration_w1:3.1e-04,update_ration_w2:3.2e-04
# Epoch:64/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0170210283152,update_ration_w1:3.2e-04,update_ration_w2:3.2e-04
# Epoch:65/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0157566631914,update_ration_w1:2.7e-04,update_ration_w2:2.9e-04
# Epoch:66/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0174824674484,update_ration_w1:2.9e-04,update_ration_w2:3.0e-04
# Epoch:67/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0152613128597,update_ration_w1:2.4e-04,update_ration_w2:2.5e-04
# Epoch:68/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0165597646418,update_ration_w1:2.5e-04,update_ration_w2:2.6e-04
# Epoch:69/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0153517536212,update_ration_w1:2.2e-04,update_ration_w2:2.3e-04
# Epoch:70/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0172815663383,update_ration_w1:2.4e-04,update_ration_w2:2.4e-04
# Epoch:71/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0162554742376,update_ration_w1:2.1e-04,update_ration_w2:2.2e-04
# Epoch:72/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.016235054344,update_ration_w1:2.0e-04,update_ration_w2:2.1e-04
# Epoch:73/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0152470772312,update_ration_w1:1.8e-04,update_ration_w2:1.8e-04
# Epoch:74/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0164202156674,update_ration_w1:1.8e-04,update_ration_w2:1.9e-04
# Epoch:75/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0157542512846,update_ration_w1:1.7e-04,update_ration_w2:1.7e-04
# Epoch:76/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0152128294221,update_ration_w1:1.5e-04,update_ration_w2:1.6e-04
# Epoch:77/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0158175493843,update_ration_w1:1.5e-04,update_ration_w2:1.5e-04
# Epoch:78/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0156844393667,update_ration_w1:1.4e-04,update_ration_w2:1.5e-04
# Epoch:79/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0170984248492,update_ration_w1:1.5e-04,update_ration_w2:1.5e-04
# Epoch:80/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0168372696551,update_ration_w1:1.4e-04,update_ration_w2:1.4e-04
# Epoch:81/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0160237117551,update_ration_w1:1.2e-04,update_ration_w2:1.3e-04
# Epoch:82/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0163369601803,update_ration_w1:1.2e-04,update_ration_w2:1.3e-04
# Epoch:83/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0182002112738,update_ration_w1:1.3e-04,update_ration_w2:1.3e-04
# Epoch:84/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0157711382008,update_ration_w1:1.0e-04,update_ration_w2:1.1e-04
# Epoch:85/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0172375633023,update_ration_w1:1.1e-04,update_ration_w2:1.1e-04
# Epoch:86/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0160763364236,update_ration_w1:9.6e-05,update_ration_w2:1.0e-04
# Epoch:87/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.014966107883,update_ration_w1:8.4e-05,update_ration_w2:8.8e-05
# Epoch:88/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0169604321412,update_ration_w1:9.2e-05,update_ration_w2:9.5e-05
# Epoch:89/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0167360049286,update_ration_w1:8.7e-05,update_ration_w2:9.0e-05
# Epoch:90/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0154063157764,update_ration_w1:7.5e-05,update_ration_w2:7.8e-05
# Epoch:91/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0167353274191,update_ration_w1:7.8e-05,update_ration_w2:8.1e-05
# Epoch:92/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0147204384457,update_ration_w1:6.4e-05,update_ration_w2:6.8e-05
# Epoch:93/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0161026878005,update_ration_w1:6.7e-05,update_ration_w2:7.0e-05
# Epoch:94/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0160291893541,update_ration_w1:6.3e-05,update_ration_w2:6.6e-05
# Epoch:95/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0156333379664,update_ration_w1:5.9e-05,update_ration_w2:6.1e-05
# Epoch:96/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0151530295233,update_ration_w1:5.4e-05,update_ration_w2:5.8e-05
# Epoch:97/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0137309585983,update_ration_w1:4.6e-05,update_ration_w2:4.9e-05
# Epoch:98/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0151976524511,update_ration_w1:4.8e-05,update_ration_w2:5.1e-05
# Epoch:99/100, Train accuracy:1.0, Validation accuracy:1.0, loss0.0171496079387,update_ration_w1:5.3e-05,update_ration_w2:5.4e-05
# Final training loss:  0.0171496079387

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = range(num_training, num_training + num_validation)
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = range(num_training)
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = range(num_test)
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
print 'Test data shape: ', X_test.shape
print 'Test labels shape: ', y_test.shape
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD with momentum. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.5, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print 'Validation accuracy: ', val_acc
# Out:
# Epoch:0/4, Train accuracy:0.135, Validation accuracy:0.115, loss2.30295425633,update_ration_w1:3.9e-04,update_ration_w2:7.6e-03
# Epoch:1/4, Train accuracy:0.175, Validation accuracy:0.189, loss2.29375084849,update_ration_w1:2.5e-03,update_ration_w2:9.4e-03
# Epoch:2/4, Train accuracy:0.285, Validation accuracy:0.225, loss2.09151543925,update_ration_w1:5.0e-03,update_ration_w2:6.6e-03
# Epoch:3/4, Train accuracy:0.245, Validation accuracy:0.246, loss2.07230225619,update_ration_w1:4.0e-03,update_ration_w2:3.6e-03
# Epoch:4/4, Train accuracy:0.32, Validation accuracy:0.288, loss1.97282749004,update_ration_w1:4.1e-03,update_ration_w2:3.0e-03
# Validation accuracy:  0.287

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
  W1 = net.params['W1']
  W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
  plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
  plt.gca().axis('off')
  plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. For every 1% above 52% on the Test set we will award you with one extra bonus point. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
input_size = 32 * 32 * 3
hidden_size = 200
num_classes = 10
best_val = -1


# Train the network
num_iters = 1800
batch_size=200
# hyperparameters
learning_rates = [8e-4]
regs = [5e-2]
learning_rate_decays = [0.95]
for lr in learning_rates:
    for reg in regs:
        for decay in learning_rate_decays:
            print("learning rate: {}, regulation: {}, decay: {}".format(lr, reg, decay))
            net = TwoLayerNet(input_size, hidden_size, num_classes)
            net.train(X_train, y_train, X_val, y_val,
                              num_iters=num_iters,
                              batch_size=batch_size,
                              learning_rate=lr,
                              learning_rate_decay= decay,
                              reg=reg,
                              verbose=False)


            # Predict on the validation set
            val_acc = (net.predict(X_val) == y_val).mean()
            train_acc = (net.predict(X_train) == y_train).mean()
            if val_acc > best_val:
                best_net = net
                best_val = val_acc
            print 'Train accuracy:{}, Validation accuracy:{}'.format(train_acc, val_acc)
print 'Best accuracy:{}'.format(best_val)
#################################################################################
#                               END OF YOUR CODE                                #
#################################################################################
# Out:
# learning rate: 0.0008, regulation: 0.05, decay: 0.95
# Epoch:0/7, Train accuracy:0.205, Validation accuracy:0.164, loss2.30272740961,update_ration_w1:3.8e-03,update_ration_w2:6.7e-02
# Epoch:1/7, Train accuracy:0.4, Validation accuracy:0.385, loss1.6811760027,update_ration_w1:3.4e-02,update_ration_w2:2.3e-02
# Epoch:2/7, Train accuracy:0.45, Validation accuracy:0.441, loss1.66615734389,update_ration_w1:3.2e-02,update_ration_w2:1.9e-02
# Epoch:3/7, Train accuracy:0.525, Validation accuracy:0.447, loss1.52057018641,update_ration_w1:2.7e-02,update_ration_w2:1.5e-02
# Epoch:4/7, Train accuracy:0.545, Validation accuracy:0.474, loss1.54748601021,update_ration_w1:2.6e-02,update_ration_w2:1.5e-02
# Epoch:5/7, Train accuracy:0.535, Validation accuracy:0.479, loss1.44558814678,update_ration_w1:2.5e-02,update_ration_w2:1.4e-02
# Epoch:6/7, Train accuracy:0.595, Validation accuracy:0.487, loss1.34175833377,update_ration_w1:2.1e-02,update_ration_w2:9.8e-03
# Epoch:7/7, Train accuracy:0.645, Validation accuracy:0.485, loss1.2818146347,update_ration_w1:1.8e-02,update_ration_w2:9.7e-03
# Train accuracy:0.561285714286, Validation accuracy:0.513
# Best accuracy:0.513

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.
#
# **We will give you extra bonus point for every 1% of accuracy above 52%.**

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print 'Test accuracy: ', test_acc
# Out:
# Test accuracy:  0.527
